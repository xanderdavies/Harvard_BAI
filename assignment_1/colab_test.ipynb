# %% [markdown]
# <a href="https://colab.research.google.com/github/Spandan-Madan/Harvard_BAI/blob/main/assignment_1/colab_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/Harvard_BAI')

# %%
with open('/content/drive/MyDrive/access_token.txt','r') as F:
    token = F.readlines()

# %%
token[0]
# Out:
# ['f2b34526596d8abffc2c536391c43b7a018d12b2']

# %%
# !ls /content/drive/MyDrive/

# %%
# !ssh-keygen -t rsa -b 4096

# %%
# !ssh-keyscan -t rsa github.com >> /content/drive/MyDrive/ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-c34a939f

# %%
# !cat /content/drive/MyDrive/ssh/id_rsa.pub
# Out:
# ssh-rsa ... root@05c7a047f4d6

# %%
print('I have made some changes, again!')
# Out:
# I have made some changes, again!

# %%
# !git add assignment_1/

# %%
# !git commit -m "confirming that git commit works."
# Out:
# [main 177845c] confirming that git commit works.
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite assignment_1/colab_test.ipynb (98%)

# %%
# !ssh -T git@github.com
# Out:
# Host key verification failed.

# %%
# !git config --global user.email "spandan_madan@g.harvard.edu"
# !git config --global user.name "Spandan-Madan"

# %%
# !git remote rm origin

# %%
# !git remote add origin https://Spandan-Madan:3ab36ec464721141812b7caf16c869dfe11d40ca@github.com/Spandan-Madan/Harvard_BAI.git

# %%
# !git push -u origin main
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://Spandan-Madan:3ab36ec464721141812b7caf16c869dfe11d40ca@github.com/Spandan-Madan/Harvard_BAI.git/'

# %%
https://github.com/Spandan-Madan/Harvard_BAI.git
